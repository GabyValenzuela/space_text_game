# %% [markdown]
# <div style="padding-right: 2em">
# <br>
# <span><small>Text Game</small></span>
# <span style="float: right"><small>Updated On: 2023-11-22</small></span>
#
#
# <center>
#     <h2 style="margin-top: 1.5em; color: #000">Space Text Adventure Game</h2>
#     <div style="margin-right: 3.5em"><table border="0">
#         <tr><td>Programming Language:&nbsp;</td> <td><span style="padding-right: 3.8em">Python</span></td></tr>
#         <tr><td>Author:&nbsp;</td>     <td><span style="padding-right: 2.0em">Gabriela Valenzuela</span></td></tr>
#         <tr><td>Date:&nbsp;</td>       <td><span style="padding-right: 4em">November 19th, 2023</span></td></tr>
#         <tr><td colspan="2"></td></tr><img src="./spaceship_image.png" width="120px" /></td></tr>
#     </table></div>
# </center>
#
# </div>

# %% [markdown]
# <font color=black> **Welcome to the SpaceX-213 Game** </font>
#
#
# <span><small>The purpose of this game is to take the user into a spaceship trip, which has the objective of reaching planet N20-XF809 that is supposed to be inhabitated by another intelligent life. The challenge of the game will be to make the user reach that planet or if that is not possible, to connect with this intelligent life and come back home with all its crew. During this trip the user will be given a couple of choices that will take them to a win or failure outcome.</small></span>
#
# </span><small>Hope you enjoy the game!</small></span>

# %%
"""
######################## WELCOME TO THE TEXT SPACESHIP GAME #############################

This is a text game in Python based on a spaceship mission. This game has 5 main stages:
        1 Mission Space
        2 Traveling Space
        3 Out of Via Lactea
        4 Planets
        5 Uncertainty
    As well as the Win (6) and Fail (7) scenarios

In the very first two stages, the user will keep advancing to other stages, and only as they 
start the 3rd stage (Out of Via Lactea) the game will start with the user making decisions about their journey.

I hope you have a good time playing this game! Comments and improvements are accepted.
"""

# Inserting packages used during this game
import time
import os, sys, time
import textwrap

# Defined function to slow text display letter by letter
def print_slow(s, speed, tail):
   for letter in s:
      print(letter, end="")
      sys.stdout.flush()
      time.sleep(speed)
   print(end=tail)

# Welcoming User
print("""
    __        __   _                            _        
    \ \      / /__| | ___ ___  _ __ ___   ___  | |_ ___  
     \ \ /\ / / _ \ |/ __/ _ \| '_ ` _ \ / _ \ | __/ _ \ 
      \ V  V /  __/ | (_| (_) | | | | | |  __/ | || (_) |
       \_/\_/ \___|_|\___\___/|_| |_| |_|\___|  \__\___/ 
     ____                      __  __    ____  _ _____   
    / ___| _ __   __ _  ___ ___\ \/ /   |___ \/ |___ /   
    \___ \| '_ \ / _` |/ __/ _ \\  /_____ __) | | |_ \   
     ___) | |_) | (_| | (_|  __//  \_____/ __/| |___) |  
    |____/| .__/ \__,_|\___\___/_/\_\   |_____|_|____/   
          |_|  _                 _                  _    
      __ _  __| |_   _____ _ __ | |_ _   _ _ __ ___| |   
     / _` |/ _` \ \ / / _ \ '_ \| __| | | | '__/ _ \ |   
    | (_| | (_| |\ V /  __/ | | | |_| |_| | | |  __/_|   
     \__,_|\__,_| \_/ \___|_| |_|\__|\__,_|_|  \___(_)   
""")
time.sleep(1) 

welcome_speed = 0.001 ######## to restablished to 0.3

print_slow(f"""
In this game you'll prove your ability as a commander of a spaceship.\n
Your mission if you accept it, is to reach planet N20-XF809 which is supposed to be
inhabited by another intelligent life and to make contact with them.\n
Either way, if you reach the planet or make contact with intelligent life your mission
will be completed.
""", welcome_speed, "\n\n")
time.sleep(1)

print_slow(f"""Are you ready to play?\n""", welcome_speed, "\n")
time.sleep(1)

#Making user start the game
print(f"""\n< Please type enter to start >""")
input(prompt = f""" """)
time.sleep(1)

#Defining speed for Mayday message
mayday_speed = 0.01
print_slow(f"""\n ...Mayday mayday we need assistance here!!!...""", mayday_speed, "\n\n")
time.sleep(2)

############################################################################################
############################### MISSION SPACE STAGE ########################################

# Defining MISSION SPACE stage
def mission_space():
    #Defining global variable for user name throughout the game
    global capitain_name

    print_slow(f"""
    It's 2100 here on Earth, and you are the commander of Space X-213.\n
    Yes, the same type as that one launched by Tesla in 2020, but after 212 more launches\n\
    and many, many more improvements!
    
    Your mission as a commander is to arrive on a new planet called N20-XF809 which is\n\
    in Hoag's Object Galaxy.\n """, welcome_speed, "\n")

    #Giving the user a space for reading and interacting
    input(prompt = """\n Please type enter to continue \n""")
    
    print_slow(f"""
    Your mission is to go there and investigate an intelligent life that sent a message
    two months ago and to come back safe and sound with all your crew.
    
    This trip won't be easy as a leader you'll have to make hard decisions that may
    or may not bring you back. """, welcome_speed, "\n")
    
    #Asking user's name
    print(f"""
    But before we start, please Captain, can you tell me your name: \n """)
    user_name = input(prompt = "") 
    capitain_name = user_name.capitalize()

    #Launching message
    launching_speed = 0.02

    print_slow(f"""
    \n 1 \n
    \n 2 \n
    \n 3...\n
    Launching Capitain {capitain_name}!!!""", launching_speed, "\n")
    
    #Giving the user a space for reading and interacting
    input(prompt = """ \n Please type enter to continue \n """)
    
    #Taking user to the following stage
    traveling_space()


############################################################################################
############################ TRAVELING SPACE STAGE  ########################################

# Defining TRAVELING SPACE stage
def traveling_space():
    print_slow(f"""
    You're finally in space and there have been a couple of hours since you left Earth...
    
    How does it make you feel?""", welcome_speed, "\n")
    
    print_slow(f"""
    1. Excited! Never been better before!\n
    2. Fearful! What if something goes wrong?\n
    3. Not so sure...
    
    < Please type your answer > """, welcome_speed, "")

    #Creating a while loop in case a user doesn't input any of the suggested options
    while True:
        feeling = input(prompt = "")
        
        feelings_1 = ["1", "1.", "one", "excited", "Excited", "EXCITED", "never better"]
        feelings_2 = ["2", "2.", "two", "fearful", "Fearful", "FEARFUL"]
        feelings_3 = ["3", "3.", "three", "not sure", "not so sure", "Not so sure", "Not so sure..."]
        
        if feeling in feelings_1:
            print_slow(f"""
            GREAT! That is the adventure spirit!\n""", welcome_speed, "\n")
            break
            
        elif feeling in feelings_2:
            print_slow(f"""
            Well, you're right to be worried lots of things can go wrong, but don't worry, 
            I have faith in you succeeding!!!""", welcome_speed, "\n")
            break
            
        elif feeling in feelings_3:
            print (f"""
            That's understandable, this is a whole new experience... 
            What if I tell you that you stand a really good chance of completing this mission.
            
            Will that give you more hope?\n
            < Please type Y/N >\n""")

            motiviation_answer= input(prompt= "")
            
            motivation_y = ["yes", "Y", "y"]
            
            if motiviation_answer in motivation_y :
                print("""\n\nHooray!!! I'm glad you're up for the challenge!!!\n""")
            else :
                print("""\n\nHopefully you'll be more enthusiastic as you spend more time on space.\n""")
            break
        
    
        else :
            print (f"""\nI'm sorry, I didn't get how you feel. Please submit your answer again, and try selecting a number!\n""")
    
    #Sending the user to "out_of_vialactea" stage
    out_of_vialactea()

############################################################################################
################################ OUT OF VIA LACTEA  ########################################

### Defining stage... OUT OF VIA LACTEA!!!   First decisions where the user could potentially be sent to the "fail" stage
def out_of_vialactea():
    print_slow(f"""
    You've just passed the Via Lactea Galaxy belt, a crucial and difficult task\n\
    that you managed well except for the fact that your orbiter was hit by a meteorit\n\
    that led you to take one of the following actions...
    
    1. Ask for assistance and call home to go back. \n
    2. Go to the closest planet and wait for Earth to send spare parts, which will let you \n\
    continue with your mission. \n
    3. Let know to the station that you'll continue and will expect to find some luck on your way!""", welcome_speed, "\n")
    
    while True:
        dec_lof = input(prompt = """\nPlease type the number of your choice (1-3)\n\n""")
        if dec_lof.isnumeric():
            break
        else:
            print("Please insert a numerical value")
            
    #Their decision will take them to a different stage
    if dec_lof == "1" :
        print (f"""
        Well, that was the safest decision. You're now heading home
        \n""")
        fail()
    
    elif dec_lof == "2" :
        print (f"""\n There are four options of planets nearby:\n
        1. Dagon, known for its high temperatures and being ~25 light-years away from Earth \n
        2. Tadmor, known for its frozen temperatures\n
        3. Kapteyn b, known as the oldest planet discovered in the Universe\n
        4. Kepler-62f, known for its deep craters on the surface \n""")
        planets()
    
    elif dec_lof == "3":
        print (f"""You really took an intrepid approach!\n""")
        #Taking user to uncertainty stage
        print("uncertainty, to be deleted later")
        uncertainty()
    
    else :
        print("""Please type a number between 1 and 3""") ####To be checked all together
        #out_of_vialactea() 


############################################################################################
#################################### PLANETS STAGE  ########################################

def planets():
    print("""
    Which planet would you like to visit?\n
    \t\tPlease type the number of your option (1-4)""")
    
    selected_planet = None
    
    while selected_planet != "3":
        selected_planet = input("""\n""")
        
        if selected_planet.isnumeric():
            if selected_planet == "3":
                print("""
                That's right "Kapteyn b" is the most convenient planet. You're back on track towards planet N20-XF809\n""")
                uncertainty()
            else:
                print("""
                It looks like that planet wasn't ideal. Why don't you give it another try.\n
                Please try with another number.""")
        else:
            print("Please insert a numerical value")

#planets()


############################################################################################
################################## UNCERTAINTY STAGE  ######################################

def uncertainty():
    print(f"""\n
        Now, you realize that now you are heading towards a black hole:\n
        1. You could keep heading towards the black hole\n
        2. Head towards a spaceship that doesn't look like anything previously designed by humans\n
        < Please type the number of your next action >\n""")
    
    while True:
        un_decision = input()
        if un_decision.isnumeric():
            if un_decision == "1" :
                print("""\nOh nooooooo... you spaguetized SpaceX-213 and all your crew!!!!!\n""")
                #Sending the user to the failure stage
                fail()
                break
            elif un_decision == "2" :
                print ("""\nHow lucky!!! The spaceship was actually from N20-XF809 inhabitants\n""")
                #Sending the user to the winning stage
                win()
                break
            else:  
                print("""\nPlease enter a numerical value between 1 and 2\n""")
        else:
            print("\tPlease insert a numerical value.\n")
 

############################################################################################
#################################### WINNING STAGE #########################################

#Defining WINNING stage!!!
def win():
    ###global capitain_name ###put back if my test doesn't work
    
    print_slow(f"""
    CONGRATULATIONS Capitain {capitain_name}!!! You made it till the end!!!\n
    You were able to communicate with inhabitants of planet N20-XF809, which by the way, were really nice\n\
    and you even got back home with a selfie with them.\n\n""", welcome_speed, "")

    print("""
    
                    __        _______ _     _       ____   ___  _   _ _____ _ _ _  
                    \ \      / / ____| |   | |     |  _ \ / _ \| \ | | ____| | | | 
                     \ \ /\ / /|  _| | |   | |     | | | | | | |  \| |  _| | | | | 
                      \ V  V / | |___| |___| |___  | |_| | |_| | |\  | |___|_|_|_| 
                       \_/\_/  |_____|_____|_____| |____/ \___/|_| \_|_____(_|_|_) 
    
    """)

    print("""
                                        +
                                
                                                 *       +
                                           '                  |
                                       ()    .-.,="``"=.    - o -
                                             '=/_       \     |
                                          *   |  '=._    |
                                               \     `=./`,        '
                                            .   '=.__.=' `='      *
                                   +                         +
                                        O      *        '       .
   
    """)
#win()

############################################################################################
#################################### FAIL STAGE #########################################

def fail():
    
    #Fail stage message
    print_slow(f"""
    I'm afraid to inform you Capitain {capitain_name}, that you didn't complete the mission \n\
    and becuase of that reason the Earth was invaded by the inhabitants of planet N20-XF809.\n
                                        So baaaad!!!""", welcome_speed, "")
    
    #Giving the user another try
    print(f"""
    Capitain {capitain_name}: Would you like to give it another try? (Y/N)\n
    """)
    play_again = input(prompt = "> ")
    play_again = play_again.lower()
    
    #If the user wants to play again, it will accept certain letters according\
    #to what was given in the instructions
    if play_again in ['yes', "Y", "y", "YES"]:
        #if a user wants to play again, they will be sent directly to the first stage
        mission_space()
        
    #Final message - if the user decides not to play again or if they enter an invalid answer    
    else:
        print(f"""\n\nThanks for playing {capitain_name}...\n\n
        It was a pleasure to interact with you today!!!\n\n""")
        print("""
                             _____ _            _____           _ _ 
                            |_   _| |__   ___  | ____|_ __   __| | |
                              | | | '_ \ / _ \ |  _| | '_ \ / _` | |
                              | | | | | |  __/ | |___| | | | (_| |_|
                              |_| |_| |_|\___| |_____|_| |_|\__,_(_)


              
              """)    


#################################################################################
#################################################################################

#Executing the whole mission function ******GAME*****       
mission_space()
